# %% [markdown]
# # Análise Exploratória de Dados (EDA) - Anúncios de Vendas de Carros
#
# Este notebook demonstra o uso de **Pandas** e **Plotly Express** para explorar o conjunto de dados `vehicles_us.csv` para o projeto do curso.

# %%
# %pip install pandas plotly
# Out:
# ...
#   Using cached plotly-6.9.0-py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 6.0 MB/s  0:00:01eta 0:00:01
# Using cached plotly-6.9.0-py3-none-any.whl (9.9 MB)
# Using cached narwhals-2.24.0-py3-none-any.whl (461 kB)
# Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [pandas]2m5/6 [pandas]s]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "notebook"
# Lendo os dados
car_data = pd.read_csv('../vehicles_us.csv')

# Exibir as primeiras linhas
car_data.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
import plotly.io as pio
pio.renderers.default = "vscode"

# %%
# Informações gerais sobre o conjunto de dados
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
# Criar um histograma para a coluna 'odometer'
fig_hist = px.histogram(car_data, x="odometer", title="Distribuição de Quilometragem (Odometer)")
fig_hist.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 # Criar um histograma para a coluna 'odometer'
#       2 fig_hist = px.histogram(car_data, x="odometer", title="Distribuição de Quilometragem (Odometer)")
# ----> 3 fig_hist.show()
#
# File /opt/homebrew/lib/python3.10/site-packages/plotly/basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)
#    3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
# ...

# %%
# Criar um gráfico de dispersão de Preço x Quilometragem
fig_scatter = px.scatter(
    car_data, 
    x="odometer", 
    y="price", 
    color="condition",
    title="Preço x Quilometragem por Condição do Veículo"
)
fig_scatter.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 9
#       1 # Criar um gráfico de dispersão de Preço x Quilometragem
#       2 fig_scatter = px.scatter(
#       3     car_data,
#       4     x="odometer",
#    (...)
#       7     title="Preço x Quilometragem por Condição do Veículo"
#       8 )
# ----> 9 fig_scatter.show()
#
# File /opt/homebrew/lib/python3.10/site-packages/plotly/basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)
#    3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...
